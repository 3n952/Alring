# %% [markdown]
# # yolov5를 이용한 보행 위험 객체 탐지 for android

# %% [markdown]
# 환경 설정 및 모듈 설치

# %%
# !pip install IPython

# %%
# !pip3 install --pre torch torchvision torchaudio --index-url https://download.pytorch.org/whl/nightly/cpu

# %%
torch.cuda.empty_cache()

# %%
# !git clone https://github.com/ultralytics/yolov5

# %%
import torch
from IPython.display import Image
torch.__version__
print(torch.backends.mps.is_available())
print(torch.backends.mps.is_built())
torch.cuda.empty_cache()

# %cd yolov5
# Out:
# True
# True
# /Users/san/workspace/AI2_project/yolov5

# %%
# !pip install -r requirements.txt

# %%
# !pip install IProgress

# %%
from tqdm import tqdm
import IProgress
from ipywidgets import IntProgress

# %% [markdown]
# yolov5 모델 훈련
#
# #weight yolov5s.pt로 해보고 cfg만 선언했을 때로도 해보기

# %%
# !python train.py --batch 16 --epochs 5 --data bollard_test.yaml --cfg ./models/yolov5s.yaml  --weights yolov5s.pt --name bollard_test
# Out:
# train: weights=yolov5s.pt, cfg=./models/yolov5s.yaml, data=bollard_test.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=5, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=bollard_test, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# requirements: /Users/san/workspace/AI2_project/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-145-g94714fe Python-3.10.9 torch-2.1.0.dev20230406 CPU
#
# ...

# %%
#테스트용
# 완료 !python detect.py --weights "yolov5s.pt" --source "./data/test1.jpg"

# %%
# !python detect.py --weights './runs/train/bollard_test2/weights/best.pt' --source './data/bollard_test.jpg'
# Out:
# detect: weights=['./runs/train/bollard_test2/weights/best.pt'], source=./data/bollard_test.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /Users/san/workspace/AI2_project/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-145-g94714fe Python-3.10.9 torch-2.1.0.dev20230406 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /Users/san/workspace/AI2_project/yolov5/data/bollard_test.jpg: 480x640 6 bollards, 74.8ms
# Speed: 0.7ms pre-process, 74.8ms inference, 6.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp
